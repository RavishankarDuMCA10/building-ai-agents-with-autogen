# %% [markdown]
# # Creating agents for the Assistant

# %%
## import required libraries
import os
from autogen import ConversableAgent, UserProxyAgent
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
## llm configuration
llm_config = {
    "model": "gpt-4o",
    "api_key": os.getenv("OPENAI_API_KEY")
}

# %% [markdown]
# ## Manager Proxy Agent

# %%
manager_proxy_agent = UserProxyAgent(
    name="Manager",
    system_message="You are a marketing campaign manager. Your role is to provide campaign topics and evaluate the ideas and scripts generate by the creative team.",
    human_input_mode="NEVER",
    code_execution_config=False,
    llm_config=llm_config
)

# %% [markdown]
# ## Idea Generator Agent

# %%
idea_generator = ConversableAgent(
    name="Idea_Generator",
    system_message='''You are a creative marketing expert. Your role is to:
    1. Generate innovative campaign ideas based on the given topic
    2. Suggest potential storylines and characters for video content
    3. Provide a brief outline for each idea
    Present 3-5 unique ideas for each request.''',
    llm_config=llm_config,
    human_input_mode="NEVER"
)

# %% [markdown]
# ## Script Writer Agent

# %%
script_writer = ConversableAgent(
    name="Script_Writer",
    system_message='''You are an expert script writer for marketing videos. Your role is to:
    1. Develop full scripts based on the provided campaign ideas
    2. Include dialogue, scene descriptions, and camera directions
    3. Ensure the script aligns with the campaign objectives and target audience
    Aim for scripts of 2-3 minutes in length.''',
    llm_config=llm_config,
    human_input_mode="NEVER"
)

# %% [markdown]
# ## Script Reviewer Agent

# %%
script_reviewer = ConversableAgent(
    name="Script_Reviewer",
    system_message='''You are a critical script reviewer. Your role is to:
    1. Analyze scripts for effectiveness, engagement, and alignment with campaign goals
    2. Provide constructive feedback on dialogue, pacing, and overall structure
    3. Suggest improvements or alternatives where necessary
    4. Ensure the script adheres to brand guidelines and target audience perferences
    Be thorough and specific in your feedback.''',
    llm_config=llm_config,
    human_input_mode="NEVER"
)

# %% [markdown]
# ## Add tasks for agents

# %%
chats = [
    {
        "sender": manager_proxy_agent,
        "recipient": idea_generator,
        "message": 
            "Hello, I need creative ideas for our new marketing campaign. "
            "Our product is eco-friendly home cleaning products. "
            "Could you generate 3-5 innovative campaign ideas, including potential "
            "storylines and characters for video content?",
        "summary_method": "reflection_with_llm",
        "summary_args": {
            "summary_prompt" : "Summarize the generated ideas "
                             "into a JSON object: "
                             "{'idea1': {'concept': '', 'storyline': '', 'characters': ''}, "
                             "'idea2': {...}, 'idea3': {...}}",
        },
        "max_turns": 2,
        "clear_history" : True
    },
    {
        "sender": manager_proxy_agent,
        "recipient": script_writer,
        "message": 
            "Great ideas! Let's develop a script for the following concept: "
            "[INSERT SELECTED IDEA HERE]. "
            "Please write a full script including dialogue, scene descriptions, "
            "and camera directions. Aim for a 2-3 minute video.",
        "summary_method": "reflection_with_llm",
        "summary_args": {
            "summary_prompt" : "Provide a brief summary of the script "
                             "as a JSON object: "
                             "{'title': '', 'main_characters': [], 'key_scenes': [], "
                             "'estimated_duration': ''}",
        },
        "max_turns": 1,
        "clear_history" : False
    },
    {
        "sender": manager_proxy_agent,
        "recipient": script_reviewer,
        "message": "Please review the following script: [INSERT SCRIPT HERE]. "
                   "Analyze it for effectiveness, engagement, and alignment with "
                   "our eco-friendly cleaning products campaign. Provide constructive "
                   "feedback and suggest improvements.",
        "max_turns": 1,
        "summary_method": "reflection_with_llm",
        "summary_args": {
            "summary_prompt" : "Summarize the review points "
                             "as a JSON object: "
                             "{'strengths': [], 'weaknesses': [], 'suggestions': []}",
        },
    },
    {
        "sender": manager_proxy_agent,
        "recipient": manager_proxy_agent,
        "message": "Based on the script and review, decide if the script is ready "
                   "for production or needs revisions. If revisions are needed, "
                   "specify the key areas to address.",
        "max_turns": 1,
        "summary_method": "reflection_with_llm",
        "summary_args": {
            "summary_prompt" : "Summarize the decision "
                             "as a JSON object: "
                             "{'decision': 'ready'/'needs_revision', "
                             "'key_revision_areas': []}",
        },
    },
]

# %% [markdown]
# ## Start researching

# %%
from autogen import initiate_chats

chat_results = initiate_chats(chats)
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Manager (to Idea_Generator):
#
# Hello, I need creative ideas for our new marketing campaign. Our product is eco-friendly home cleaning products. Could you generate 3-5 innovative campaign ideas, including potential storylines and characters for video content?
#
# --------------------------------------------------------------------------------
# Idea_Generator (to Manager):
#
# Absolutely, let's explore some fresh and engaging campaign ideas for your eco-friendly home cleaning products:
#
# 1. **"Clean Start Challenge" Campaign**
#    - **Outline**: Launch a social media challenge where families are invited to switch to eco-friendly cleaning products for 30 days. Participants document their journey, sharing weekly updates and transformations.
#    - **Storyline & Characters**: Introduce a diverse family, "The Greens," who document their transition and the impacts of using eco-friendly products. Highlight the perspectives of different family members, from kids to grandparents, showcasing the benefits in creative ways like animated germs being washed away by smiling, plant-powered cleaning solutions.
#    - **Idea Expansion**: Encourage user-generated content where families around the world share videos and stories of their sustainable cleaning journeys.
#
# 2. **"Eco Hero Academy" Series**
#    - **Outline**: Create a web series that follows students at the fictional "Eco Hero Academy," where green warriors learn how to save the planet, starting with their homes.
#    - **Storyline & Characters**: Feature a quirky professor, Dr. Greenfingers, and a group of eager students each with unique characteristics (e.g., a tech-savvy kid, an eco-nerd, a sporty type, etc.). Each episode reveals a new eco-friendly cleaning trick, showing the science behind eco-friendly products and their benefits.
#    - **Idea Expansion**: Integrate interactive content where viewers can take short quizzes or participate in mini-tasks to earn virtual “Eco Hero” badges.
#
# 3. **"From Nature, For Nature" Campaign**
#    - **Outline**: Develop a narrative that follows the journey of natural ingredients from their source in the wild to becoming part of your cleaning solutions.
#    - **Storyline & Characters**: Switch perspectives between a wise old tree in a lush forest and the lead scientist at a green innovation lab who communicates with nature. Use heartwarming animation to illustrate the process, focusing on the symbiotic relationship between nature and product.
#    - **Idea Expansion**: Offer guided tours of your virtual lab and promote real-world eco-tours to educate consumers on sustainability.
#
# 4. **"The Magic of Clean" Mini-Movie**
#    - **Outline**: Produce a short film showcasing the magical transformation of a home when eco-friendly cleaning products are used, turning ordinary cleaning tasks into magical events.
#    - **Storyline & Characters**: Star a whimsical fairy named Clea who visits different homes, revealing the charming magic behind each eco-friendly product. As Clea uses the products, animated elements like glowing bubbles or singing plants appear, making cleaning an enchanting experience.
#    - **Idea Expansion**: Distribute via social media and partner platforms, offering augmented reality experiences where users can see the magic of clean in their own homes through filters and effects.
#
# 5. **"Every Bottle Tells a Story" User-Generated Content Campaign**
#    - **Outline**: Invite customers to share the personal stories behind their use of your products, focusing on the positive changes these products have brought to their lives and environments.
#    - **Storyline & Characters**: Feature real customers as the stars, sharing heartfelt testimonials and experiences. Include a montage of different stories, intertwining family gatherings, serene home environments, and happy pets to demonstrate the diverse impact of the products.
#    - **Idea Expansion**: Create a dedicated campaign site where users can upload their stories, with the most inspiring featured in national ads and broader marketing initiatives.
#
# These ideas cater to storytelling that not only highlights the unique benefits of your products but also involves the audience in an engaging and meaningful way.
#
# --------------------------------------------------------------------------------
# Manager (to Idea_Generator):
#
# Please evaluate these creative campaign ideas and scripts designed by our team for promoting our eco-friendly home cleaning products. Your feedback will help us fine-tune our approach and determine which concepts align best with our brand vision and marketing goals.
#
# --------------------------------------------------------------------------------
# Idea_Generator (to Manager):
#
# I'd be happy to provide feedback on your team's ideas and scripts for promoting your eco-friendly home cleaning products. If you could share some details or summarize the key concepts and scripts your team has developed, I'll evaluate them in terms of creativity, alignment with your brand vision, engagement potential, and overall effectiveness. Looking forward to helping you refine and choose the best approach for your campaign!
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (05b228d6-a226-4a8a-b369-ea79a234f570): Maximum turns (2) reached
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Manager (to Script_Writer):
#
# Great ideas! Let's develop a script for the following concept: [INSERT SELECTED IDEA HERE]. Please write a full script including dialogue, scene descriptions, and camera directions. Aim for a 2-3 minute video.
# Context:
# ```json
# {
#   "idea1": {
#     "concept": "Clean Start Challenge",
#     "storyline": "Launch a social media challenge inviting families to switch to eco-friendly cleaning products for 30 days, sharing weekly updates and transformations.",
#     "characters": "A diverse family, 'The Greens,' documenting their transition and impacts from different perspectives, including animated germs as additional characters."
#   },
#   "idea2": {
#     "concept": "Eco Hero Academy Series",
#     "storyline": "Create a web series following students at 'Eco Hero Academy,' where green warriors learn to save the planet, starting with their homes.",
#     "characters": "A quirky professor, Dr. Greenfingers, and diverse students each with unique traits like a tech-savvy kid, an eco-nerd, and a sporty type."
#   },
#   "idea3": {
#     "concept": "From Nature, For Nature",
#     "storyline": "A narrative following the journey of natural ingredients from their source in the wild to becoming a part of cleaning solutions, highlighting the relationship between nature and product.",
#     "characters": "A wise old tree and a lead scientist at a green innovation lab communicating with nature."
#   },
#   "idea4": {
#     "concept": "The Magic of Clean Mini-Movie",
#     "storyline": "A short film showcasing the magical transformation of a home when eco-friendly cleaning products are used, turning cleaning tasks into enchanting events.",
#     "characters": "A whimsical fairy named Clea and various household elements that come alive (e.g., glowing bubbles, singing plants)."
#   },
#   "idea5": {
#     "concept": "Every Bottle Tells a Story",
#     "storyline": "Invite customers to share personal stories behind their use of the products, focusing on positive life and environmental changes.",
#     "characters": "Real customers as stars sharing testimonials, with a montage of family gatherings, serene home environments, and happy pets."
#   }
# }
# ```
#
# --------------------------------------------------------------------------------
# Script_Writer (to Manager):
#
# ### Video Script: "Clean Start Challenge"
#
# #### Scene 1: Introduction
#
# **INT. THE GREENS’ LIVING ROOM – DAY**
#
# *The camera pans over a cozy, lived-in living room. Family photos of The Greens—a diverse family—line the walls. Books and toys are neatly organized. The family sits on the couch, eager to begin their journey.*
#
# **FATHER GREEN (DAVID):**
# (holding a smartphone)
# Hey, everyone! We’re the Greens, and we’re excited to share our new adventure with you.
#
# **MOTHER GREEN (AMARA):**
# We're taking on the #CleanStartChallenge, switching entirely to eco-friendly cleaning products for the next 30 days.
#
# **Camera focuses on the excited faces of their children, ELLA (12) and JAKE (8), as they chime in.**
#
# **ELLA:**
# And we’re going to update you every week!
#
# **JAKE (shaking a spray bottle):**
# But first, meet our new friends—these eco-friendly cleaning products.
#
# #### Scene 2: The Switch
#
# **INT. KITCHEN – DAY**
#
# *The camera follows Amara as she opens the cleaning cabinet, revealing a clutter of traditional cleaners. Soft, whimsical music plays as animated germs scramble around in panic.*
#
# **AMARA:**
# Say goodbye, old cleaners, and hello to a cleaner future!
#
# *She replaces the old products with eco-friendly ones. The camera zooms in on animated germs shrinking and fizzling out.*
#
# **GERM 1 (high-pitched):**
# Retreat! The humans have discovered our weakness!
#
# *The camera captures a shared family laugh.*
#
# #### Scene 3: Weekly Update #1
#
# **EXT. GARDEN – DAY**
#
# *The Greens are gardening together. David holds up his phone to record.*
#
# **DAVID:**
# Week one update—and look! Our garden is thriving without harsh chemicals.
#
# *Zoom in on Jake proudly showing a worm, who gives a thumbs-up.*
#
# **JAKE:**
# Even the worms agree!
#
# *Animated germs peer around a plant leaf, looking worried before disappearing.*
#
# #### Scene 4: Weekly Update #2
#
# **INT. BATHROOM – DAY**
#
# *Ella and Amara are in the bathroom. The camera shows Ella wiping a mirror with an eco-friendly cloth.*
#
# **AMARA:**
# Our bathroom’s never looked cleaner! No more toxic fumes—and just look at that shine.
#
# *Ella spins, showing sparkling bathroom tiles. The camera captures a reluctant animated germ waving a white flag before vanishing.*
#
# #### Scene 5: Weekly Update #4 & Finale
#
# **INT. LIVING ROOM – DAY**
#
# *The family gathers again on the couch, editing their final video update. The room is visibly brighter, plants are thriving, and everyone's beaming.*
#
# **ELLA:**
# It’s been 30 days and the results are amazing! Our home feels fresher, and so do we!
#
# **JAKE (jumping up):**
# And we’re helping save the planet!
#
# *The camera cuts to animated germs gathered in a circle, discussing going eco-friendly themselves.*
#
# **GERM 2 (smiling):**
# Alright, team, let’s go green.
#
# **MOTHER GREEN:**
# We hope our story inspires you to join the #CleanStartChallenge and make a difference!
#
# *The camera pans to the family cuddled on the sofa, waving goodbye. The screen displays the hashtag #CleanStartChallenge alongside bright, joyful music.*
#
# **Narrator (V.O.):**
# Ready for your clean start? Share your journey and spark change in your community!
#
# *The video fades out showcasing the brand’s logo, followed by contact details and the campaign hashtag.*
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (d667e68e-44fb-4d21-afac-4d7bc057120c): Maximum turns (1) reached
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Manager (to Script_Reviewer):
#
# Please review the following script: [INSERT SCRIPT HERE]. Analyze it for effectiveness, engagement, and alignment with our eco-friendly cleaning products campaign. Provide constructive feedback and suggest improvements.
# Context:
# ```json
# {
#   "idea1": {
#     "concept": "Clean Start Challenge",
#     "storyline": "Launch a social media challenge inviting families to switch to eco-friendly cleaning products for 30 days, sharing weekly updates and transformations.",
#     "characters": "A diverse family, 'The Greens,' documenting their transition and impacts from different perspectives, including animated germs as additional characters."
#   },
#   "idea2": {
#     "concept": "Eco Hero Academy Series",
#     "storyline": "Create a web series following students at 'Eco Hero Academy,' where green warriors learn to save the planet, starting with their homes.",
#     "characters": "A quirky professor, Dr. Greenfingers, and diverse students each with unique traits like a tech-savvy kid, an eco-nerd, and a sporty type."
#   },
#   "idea3": {
#     "concept": "From Nature, For Nature",
#     "storyline": "A narrative following the journey of natural ingredients from their source in the wild to becoming a part of cleaning solutions, highlighting the relationship between nature and product.",
#     "characters": "A wise old tree and a lead scientist at a green innovation lab communicating with nature."
#   },
#   "idea4": {
#     "concept": "The Magic of Clean Mini-Movie",
#     "storyline": "A short film showcasing the magical transformation of a home when eco-friendly cleaning products are used, turning cleaning tasks into enchanting events.",
#     "characters": "A whimsical fairy named Clea and various household elements that come alive (e.g., glowing bubbles, singing plants)."
#   },
#   "idea5": {
#     "concept": "Every Bottle Tells a Story",
#     "storyline": "Invite customers to share personal stories behind their use of the products, focusing on positive life and environmental changes.",
#     "characters": "Real customers as stars sharing testimonials, with a montage of family gatherings, serene home environments, and happy pets."
#   }
# }
# ```
# ```json
# {
#   "title": "Clean Start Challenge",
#   "main_characters": ["Father Green (David)", "Mother Green (Amara)", "Ella", "Jake", "Animated Germs"],
#   "key_scenes": [
#     "Introduction: The Greens introduce the #CleanStartChallenge in their living room.",
#     "The Switch: Amara replaces traditional cleaners with eco-friendly products in the kitchen.",
#     "Weekly Update #1: The family gardening with eco-friendly products; worms approve.",
#     "Weekly Update #2: Ella and Amara clean the bathroom with eco-friendly products.",
#     "Weekly Update #4 & Finale: Family shares successful completion of the challenge and encourages others to join."
#   ],
#   "estimated_duration": "2-3 minutes"
# }
# ```
#
# --------------------------------------------------------------------------------
# Script_Reviewer (to Manager):
#
# **Title: Clean Start Challenge Script Review**
#
# ### Effectiveness and Engagement
#
# 1. **Introduction:**
#    - The introductory scene must capture the attention immediately and effectively communicate the challenge's purpose.
#    - Suggestion: Open with an engaging hook, possibly a short montage of everyday cleaning but with an exaggerated negative environmental impact (e.g., animated pollutants).
#
# 2. **Character Engagement:**
#    - The "Greens" should be relatable and dynamic to ensure audience interest.
#    - Suggestion: Include short backstory elements or 'day-in-the-life' snippets that highlight each character’s unique take on the challenge. For example, Ella could be an aspiring ecologist, adding depth.
#
# 3. **Animated Germs:**
#    - These characters need to play more than just an adversary role; consider them adding humor and education.
#    - Suggestion: Use them to dramatize the switch by showing their exaggerated reactions to eco-friendly products, underscoring the effectiveness humorously.
#
# ### Dialogue, Pacing, and Structure
#
# 1. **Dialogue:**
#    - Keep dialogue natural and concise. Lines should feel like authentic family interactions.
#    - Suggestion: Each key scene might benefit from memorable quotes or catchphrases related to the challenge, e.g., "Green is the new clean!"
#
# 2. **Pacing:**
#    - Ensure each scene transitions smoothly. The pacing should build excitement towards the final transformation.
#    - Suggestion: Use thematic music changes to highlight shifts from old to new product usage, adding to the narrative's rhythm.
#
# 3. **Structure:**
#    - The script must maintain a fluid storyline throughout 2-3 minutes, avoiding any abrupt jumps.
#    - Suggestion: Seamless blend of talking directly to the audience in a vlog style with engaging family interactions can enhance flow.
#
# ### Alignment with Campaign Goals
#
# 1. **Eco-Friendly Messaging:**
#    - Reinforce the benefits of eco-friendly products without being overly preachy.
#    - Suggestion: Highlight specific practical benefits like improved air quality or reduced allergies, as observed by family members during updates.
#
# 2. **Target Audience:**
#    - Tailor content to families prioritizing sustainability. Align humor and logic to resonate with them.
#    - Suggestion: Consider interactive elements or calls-to-action aimed at family units, like suggesting fun family challenges post-viewing.
#
# ### Brand Guidelines and Target Audience
#
# 1. **Brand Adherence:**
#    - Ensure that all messaging supports the overall brand vision—cleaning that cares for the environment.
#    - Suggestion: Incorporate brand colors and easy logo placements subtly within scenes.
#
# 2. **Audience Preferences:**
#    - Prioritize inclusivity and diversity to mirror a broad audience base, appreciating varied family structures.
#    - Suggestion: Feature culturally diverse meals during the kitchen scene or implement multi-language captions for accessibility.
#
# ### Conclusion
#
# The current script draft has solid potential to effectively communicate the campaign goals but can be improved by enhancing the introduction and character dynamics. Implementing these suggestions should increase engagement and ensure the narrative resonates deeply with eco-conscious families, while also inspiring them to adopt greener practices.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (55167796-02cf-41e0-aec1-e26c4d6ff0f6): Maximum turns (1) reached
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Manager (to Manager):
#
# Based on the script and review, decide if the script is ready for production or needs revisions. If revisions are needed, specify the key areas to address.
# Context:
# ```json
# {
#   "idea1": {
#     "concept": "Clean Start Challenge",
#     "storyline": "Launch a social media challenge inviting families to switch to eco-friendly cleaning products for 30 days, sharing weekly updates and transformations.",
#     "characters": "A diverse family, 'The Greens,' documenting their transition and impacts from different perspectives, including animated germs as additional characters."
#   },
#   "idea2": {
#     "concept": "Eco Hero Academy Series",
#     "storyline": "Create a web series following students at 'Eco Hero Academy,' where green warriors learn to save the planet, starting with their homes.",
#     "characters": "A quirky professor, Dr. Greenfingers, and diverse students each with unique traits like a tech-savvy kid, an eco-nerd, and a sporty type."
#   },
#   "idea3": {
#     "concept": "From Nature, For Nature",
#     "storyline": "A narrative following the journey of natural ingredients from their source in the wild to becoming a part of cleaning solutions, highlighting the relationship between nature and product.",
#     "characters": "A wise old tree and a lead scientist at a green innovation lab communicating with nature."
#   },
#   "idea4": {
#     "concept": "The Magic of Clean Mini-Movie",
#     "storyline": "A short film showcasing the magical transformation of a home when eco-friendly cleaning products are used, turning cleaning tasks into enchanting events.",
#     "characters": "A whimsical fairy named Clea and various household elements that come alive (e.g., glowing bubbles, singing plants)."
#   },
#   "idea5": {
#     "concept": "Every Bottle Tells a Story",
#     "storyline": "Invite customers to share personal stories behind their use of the products, focusing on positive life and environmental changes.",
#     "characters": "Real customers as stars sharing testimonials, with a montage of family gatherings, serene home environments, and happy pets."
#   }
# }
# ```
# ```json
# {
#   "title": "Clean Start Challenge",
#   "main_characters": ["Father Green (David)", "Mother Green (Amara)", "Ella", "Jake", "Animated Germs"],
#   "key_scenes": [
#     "Introduction: The Greens introduce the #CleanStartChallenge in their living room.",
#     "The Switch: Amara replaces traditional cleaners with eco-friendly products in the kitchen.",
#     "Weekly Update #1: The family gardening with eco-friendly products; worms approve.",
#     "Weekly Update #2: Ella and Amara clean the bathroom with eco-friendly products.",
#     "Weekly Update #4 & Finale: Family shares successful completion of the challenge and encourages others to join."
#   ],
#   "estimated_duration": "2-3 minutes"
# }
# ```
# ```json
# {
#   "strengths": [
#     "The concept focuses on a relatable family challenge, which can be engaging.",
#     "Use of animated germs adds a layer of humor and educational value.",
#     "The storyline allows for incremental updates, maintaining viewer interest over time."
#   ],
#   "weaknesses": [
#     "Introduction lacks an immediate engaging hook.",
#     "Character engagement might be insufficient without deeper backstories.",
#     "Pacing and transitions between scenes may feel abrupt if not handled smoothly.",
#     "Potential for overly preachy messages that may not resonate well."
#   ],
#   "suggestions": [
#     "Start with a visual hook highlighting negative environmental impacts creatively.",
#     "Enrich character backstories to increase relatability and interest.",
#     "Use animated germs for both humor and educational purposes.",
#     "Incorporate catchy dialogue or catchphrases relevant to the challenge.",
#     "Use thematic music to aid in smooth transitions between scenes.",
#     "Integrate specific practical benefits of eco-friendly products within updates.",
#     "Ensure content aligns with the brand's eco-friendly image and broad family appeal.",
#     "Feature diversity and inclusivity to resonate with a wider audience."
#   ]
# }
# ```
# --------------------------------------------------------------------------------
# Manager (to Manager):
#
# The script for "Clean Start Challenge" is promising but requires revisions before it's ready for production. Here are the specific areas that need to be addressed:
#
# 1. **Engaging Introduction**: The introduction should start with a strong visual hook that creatively highlights the negative environmental impacts of traditional cleaning products. This will capture the audience's attention right away.
#
# 2. **Character Development**: The script should enrich the character backstories of the Green family to increase relatability and viewer interest. This can help in establishing a stronger emotional connection with the audience.
#
# 3. **Pacing and Transitions**: Ensure that the pacing between scenes is smooth. Incorporate thematic music to aid in transitions and maintain the audience's engagement throughout the story.
#
# 4. **Dialogue and Humor**: Incorporate catchy dialogues or catchphrases to make the challenge memorable. Use the animated germs effectively for both humor and educational value, making their segments more interactive and impactful.
#
# 5. **Avoid Preachiness**: While conveying the environmental benefits, avoid using overly preachy messages. Instead, integrate specific, practical benefits of eco-friendly products within the updates to resonate better with the audience.
#
# 6. **Brand and Inclusivity Alignment**: Ensure the content aligns with the brand's eco-friendly image. Include elements of diversity and inclusivity in the character depictions and interactions to appeal to a broader audience.
#
# Once these revisions are made, the script should be in a much stronger position to engage viewers and effectively convey the intended message.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (8e403a7d-1d2d-4fe1-82f6-fdc60b3f55b3): Maximum turns (1) reached

# %%
for chat_result in chat_results:
    print(chat_result.summary)
    print("\n")
# Out:
# ```json
# {
#   "idea1": {
#     "concept": "Clean Start Challenge",
#     "storyline": "Launch a social media challenge inviting families to switch to eco-friendly cleaning products for 30 days, sharing weekly updates and transformations.",
#     "characters": "A diverse family, 'The Greens,' documenting their transition and impacts from different perspectives, including animated germs as additional characters."
#   },
#   "idea2": {
#     "concept": "Eco Hero Academy Series",
#     "storyline": "Create a web series following students at 'Eco Hero Academy,' where green warriors learn to save the planet, starting with their homes.",
#     "characters": "A quirky professor, Dr. Greenfingers, and diverse students each with unique traits like a tech-savvy kid, an eco-nerd, and a sporty type."
#   },
#   "idea3": {
#     "concept": "From Nature, For Nature",
#     "storyline": "A narrative following the journey of natural ingredients from their source in the wild to becoming a part of cleaning solutions, highlighting the relationship between nature and product.",
#     "characters": "A wise old tree and a lead scientist at a green innovation lab communicating with nature."
#   },
#   "idea4": {
#     "concept": "The Magic of Clean Mini-Movie",
#     "storyline": "A short film showcasing the magical transformation of a home when eco-friendly cleaning products are used, turning cleaning tasks into enchanting events.",
#     "characters": "A whimsical fairy named Clea and various household elements that come alive (e.g., glowing bubbles, singing plants)."
#   },
#   "idea5": {
#     "concept": "Every Bottle Tells a Story",
#     "storyline": "Invite customers to share personal stories behind their use of the products, focusing on positive life and environmental changes.",
#     "characters": "Real customers as stars sharing testimonials, with a montage of family gatherings, serene home environments, and happy pets."
#   }
# }
# ```
#
#
# ```json
# {
#   "title": "Clean Start Challenge",
#   "main_characters": ["Father Green (David)", "Mother Green (Amara)", "Ella", "Jake", "Animated Germs"],
#   "key_scenes": [
#     "Introduction: The Greens introduce the #CleanStartChallenge in their living room.",
#     "The Switch: Amara replaces traditional cleaners with eco-friendly products in the kitchen.",
#     "Weekly Update #1: The family gardening with eco-friendly products; worms approve.",
#     "Weekly Update #2: Ella and Amara clean the bathroom with eco-friendly products.",
#     "Weekly Update #4 & Finale: Family shares successful completion of the challenge and encourages others to join."
#   ],
#   "estimated_duration": "2-3 minutes"
# }
# ```
#
#
# ```json
# {
#   "strengths": [
#     "The concept focuses on a relatable family challenge, which can be engaging.",
#     "Use of animated germs adds a layer of humor and educational value.",
#     "The storyline allows for incremental updates, maintaining viewer interest over time."
#   ],
#   "weaknesses": [
#     "Introduction lacks an immediate engaging hook.",
#     "Character engagement might be insufficient without deeper backstories.",
#     "Pacing and transitions between scenes may feel abrupt if not handled smoothly.",
#     "Potential for overly preachy messages that may not resonate well."
#   ],
#   "suggestions": [
#     "Start with a visual hook highlighting negative environmental impacts creatively.",
#     "Enrich character backstories to increase relatability and interest.",
#     "Use animated germs for both humor and educational purposes.",
#     "Incorporate catchy dialogue or catchphrases relevant to the challenge.",
#     "Use thematic music to aid in smooth transitions between scenes.",
#     "Integrate specific practical benefits of eco-friendly products within updates.",
#     "Ensure content aligns with the brand's eco-friendly image and broad family appeal.",
#     "Feature diversity and inclusivity to resonate with a wider audience."
#   ]
# }
# ```
#
#
# ```json
# {
#   "decision": "needs_revision",
#   "key_revision_areas": [
#     "Engaging Introduction",
#     "Character Development",
#     "Pacing and Transitions",
#     "Dialogue and Humor",
#     "Avoid Preachiness",
#     "Brand and Inclusivity Alignment"
#   ]
# }
# ```

# %%
for chat_result in chat_results:
    print(chat_result.cost)
    print("\n")
# Out:
# {'usage_including_cached_inference': {'total_cost': 0.8158400000000001, 'gpt-4o-2024-08-06': {'cost': 0.8158400000000001, 'prompt_tokens': 271052, 'completion_tokens': 13821, 'total_tokens': 284873}}, 'usage_excluding_cached_inference': {'total_cost': 0.8158400000000001, 'gpt-4o-2024-08-06': {'cost': 0.8158400000000001, 'prompt_tokens': 271052, 'completion_tokens': 13821, 'total_tokens': 284873}}}
#
#
# {'usage_including_cached_inference': {'total_cost': 0.40980250000000007, 'gpt-4o-2024-08-06': {'cost': 0.40980250000000007, 'prompt_tokens': 140177, 'completion_tokens': 5936, 'total_tokens': 146113}}, 'usage_excluding_cached_inference': {'total_cost': 0.40980250000000007, 'gpt-4o-2024-08-06': {'cost': 0.40980250000000007, 'prompt_tokens': 140177, 'completion_tokens': 5936, 'total_tokens': 146113}}}
#
#
# {'usage_including_cached_inference': {'total_cost': 0.4097650000000001, 'gpt-4o-2024-08-06': {'cost': 0.4097650000000001, 'prompt_tokens': 140354, 'completion_tokens': 5888, 'total_tokens': 146242}}, 'usage_excluding_cached_inference': {'total_cost': 0.4097650000000001, 'gpt-4o-2024-08-06': {'cost': 0.4097650000000001, 'prompt_tokens': 140354, 'completion_tokens': 5888, 'total_tokens': 146242}}}
#
#
# {'usage_including_cached_inference': {'total_cost': 0.8198450000000002, 'gpt-4o-2024-08-06': {'cost': 0.8198450000000002, 'prompt_tokens': 284882, 'completion_tokens': 10764, 'total_tokens': 295646}}, 'usage_excluding_cached_inference': {'total_cost': 0.8198450000000002, 'gpt-4o-2024-08-06': {'cost': 0.8198450000000002, 'prompt_tokens': 284882, 'completion_tokens': 10764, 'total_tokens': 295646}}}
